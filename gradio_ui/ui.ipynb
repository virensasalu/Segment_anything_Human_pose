# %%
# !pip install gradio

# %%
import gradio as gr
#print("Gradio imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import gradio as gr
#       2 print("Gradio imported successfully!")
#
# ModuleNotFoundError: No module named 'gradio'

# %%
#Placeholder functions
def upload_person_image(person_image):
    # 

  
    return person_image

def upload_garment_image(garment_image):
    


    return garment_image

def generate_model_image(person_image, garment_image, description):
    #


    return person_image  

def final_output(model_image):
    #



    return model_image
# Out:
# zsh:1: /Users/virensasalu/Documents/coding/coding_files/SAM/Segment_anything_Human_pose/venv/bin/pip: bad interpreter: /Users/virensasalu/Documents/coding/coding_files/SAM/human-seg-inf-master/venv/bin/python3.12: no such file or directory
# Requirement already satisfied: gradio in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (5.23.3)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.115.12)
# Requirement already satisfied: ffmpy in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.8.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (1.8.0)
# Requirement already satisfied: groovy~=0.1 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.30.1)
# Requirement already satisfied: jinja2<4.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (3.10.16)
# Requirement already satisfied: packaging in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (2.11.2)
# Requirement already satisfied: pydub in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.11.4)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.46.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.15.2)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio-client==1.8.0->gradio) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from gradio-client==1.8.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.0)
# Requirement already satisfied: click>=8.0.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/virensasalu/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
def build_ui():
    with gr.Blocks() as demo:
        gr.Markdown(
            """
            # FashionFlux Virtual Try On \n
            **FashionFlux**
            """
        )

        with gr.Row():
            with gr.Column():
                #Person Image
                person_image = gr.Image(
                    label="Upload an image (Person)",
                    type="pil",
                    elem_id="person_image"
                )
                btn_upload_person = gr.Button("Upload Person Image")
            
            with gr.Column():
                #Garment
                garment_image = gr.Image(
                    label="Garment",
                    type="pil",
                    elem_id="garment_image"
                )
                btn_upload_garment = gr.Button("Upload Garment Image")

            with gr.Column():
                #Model Image Output
                model_image = gr.Image(
                    label="Model Image Output",
                    type="pil",
                    elem_id="model_image"
                )
                btn_generate_model = gr.Button("Generate Model Image")

            with gr.Column():
                #Final Output
                final_result = gr.Image(
                    label="Output",
                    type="pil",
                    elem_id="final_output"
                )
                btn_generate_final = gr.Button("Generate Final Output")

        #Description text box 
        garment_description = gr.Textbox(
            label="Description of Garment",
            placeholder="e.g. Short Sleeve, Round Neck, T-Shirt" #can use whatever we want. 
        )

        

        #using buttons to placeholder functions
        btn_upload_person.click(
            fn=upload_person_image,
            inputs=[person_image],
            outputs=[person_image]
        )

        btn_upload_garment.click(
            fn=upload_garment_image,
            inputs=[garment_image],
            outputs=[garment_image]
        )

        btn_generate_model.click(
            fn=generate_model_image,
            inputs=[person_image, garment_image, garment_description],
            outputs=[model_image]
        )

        btn_generate_final.click(
            fn=final_output,
            inputs=[model_image],
            outputs=[final_result]
        )

    return demo

# %%
if __name__ == "__main__":
    demo_app = build_ui()
    demo_app.launch()

    #can lauch
